# %%
# Import pandas as pd
import pandas as pd

# Import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
from colorama import Fore, Back, Style

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Load sales data from a CSV file into a pandas DataFrame and contains a "date" column with dates that should be parsed.
sales = pd.read_csv(r'C:\Users\YaqoobDavid\OneDrive - WOW Tech Europe GmbH\Desktop\house_analysis\house_sale_analysis\kc_house_data.csv', parse_dates=(['date']))

# %%
# Display the first two rows of the sales DataFrame
print(Style.BRIGHT+ 'Checking Dataframe Head:' + Style.RESET_ALL)
print(Style.BRIGHT+ '---------------------' + Style.RESET_ALL)
sales.head()
# Out:
# Checking Dataframe Head:
# ---------------------
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
print(Style.BRIGHT+ 'Dataframe Columns:' + Style.RESET_ALL)
print(Style.BRIGHT+ '---------------------' + Style.RESET_ALL)
sales.columns
# Out:
# Dataframe Columns:
# ---------------------
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# and uses the "tail()" function to display the last 5 rows of the DataFrame
print(Style.BRIGHT+ 'Checking Dataframe Tail:' + Style.RESET_ALL)
print(Style.BRIGHT+ '---------------------' + Style.RESET_ALL)
sales.tail()
# Out:
# Checking Dataframe Tail:
# ---------------------
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# Generate descriptive statistics of the "sales" DataFrame
print(Style.BRIGHT+ 'Checking Data Statistics:' + Style.RESET_ALL)
print(Style.BRIGHT+ '---------------------' + Style.RESET_ALL)
sales.describe()
# Out:
# Checking Data Statistics:
# ---------------------
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# Generate transposed descriptive statistics of the "sales" DataFrame It then transposes the resulting DataFrame using the "T" attribute
sales.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
print(Style.BRIGHT+ 'Dataframe Information:' + Style.RESET_ALL)
print(Style.BRIGHT+ '---------------------' + Style.RESET_ALL)
sales.info()
# Out:
# Dataframe Information:
# ---------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
# ...

# %% [markdown]
# ### What is the overall distribution of house prices?

# %%
# Create histogram of house prices
plt.style.use('seaborn-v0_8')
plt.hist(sales['price'], bins=50)
plt.xlabel('House Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting the distribution of sale prices using seaborn's distplot function
plt.style.use('seaborn-v0_8')
sns.distplot(sales['price']);
# Out:
# C:\Users\YaqoobDavid\AppData\Local\Temp\ipykernel_21944\2572351944.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sales['price']);

# %% [markdown]
# ### How many days does the dataset span for?

# %%
# Calculate the time span between the first and last sale dates
# and uses the "max()" and "min()" functions to retrieve the latest and earliest dates,
# and subtracts them to get the time span between them

time_span = sales.date.max()-sales.date.min()
time_span.days
# Out:
# 390

# %% [markdown]
# ### What are the dates that had the most sales?

# %%
# Count the number of sales for each date
sales.date.value_counts()
# Out:
# 2014-06-23    142
# 2014-06-26    131
# 2014-06-25    131
# 2014-07-08    127
# 2015-04-27    126
#              ...
# 2014-11-02      1
# 2015-01-31      1
# 2015-05-24      1
# 2014-05-17      1
# 2014-07-27      1
# Name: date, Length: 372, dtype: int64

# %% [markdown]
# ### Which homes were sold on '2014-06-23'?

# %%
# Get the date with the most sales
top_date = sales.date.mode()[0]

# Retrieve all sales data for the top date
# and selects all rows where the "date" column matches the top_date value
sales[sales.date == top_date]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 117    4060000240 2014-06-23  205425.0         2       1.00          880
# 397    5175800060 2014-06-23  365000.0         4       2.00         1940
# 470    2172000075 2014-06-23  290900.0         2       2.00         1610
# 621    3010300240 2014-06-23  577000.0         3       2.50         2060
# 676    7846700310 2014-06-23  280000.0         2       1.00         1010
# ...           ...        ...       ...       ...        ...          ...
# 21230  3629990280 2014-06-23  497000.0         3       2.25         1630
# 21479  6181500120 2014-06-23  312891.0         5       3.00         2300
# 21529  2487200490 2014-06-23  670000.0         3       2.50         3310
# 21578   567000385 2014-06-23  362500.0         2       1.50          940
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ### What are the years in which home sales took place in 2014 and 2015?

# %%
# Count the number of sales for each year and create a bar chart
plt.style.use('seaborn-v0_8')
sales['date'].dt.year.value_counts().plot(kind='bar')

# Set the chart title
plt.title('Number of Sales by Year')

# Set the x-axis label
plt.xlabel('Year')

# Set the y-axis label
plt.ylabel('Number of Sales')
# Out:
# Text(0, 0.5, 'Number of Sales')

# %% [markdown]
# ### What are all the homes sold in 2014 sorted from earliest to latest?

# %%
# Get the count of sales for each month and return the top result
sales[sales.date.dt.year == 2014].sort_values('date', ascending= True)
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 11907  3221059036 2014-05-02  400000.0         4       2.50         3630
# 20559  3438501320 2014-05-02  295000.0         2       2.50         1630
# 17038  2326059099 2014-05-02  838000.0         4       2.50         3310
# 15921  7831800460 2014-05-02  235000.0         2       1.00         1210
# 11891  7305300695 2014-05-02  625000.0         4       2.50         2820
# ...           ...        ...       ...       ...        ...          ...
# 1692   7701990700 2014-12-31  825000.0         4       2.50         3210
# 8393   2493200215 2014-12-31  582000.0         3       1.75         1820
# 18462  7345200650 2014-12-31  219200.0         3       2.00         1680
# 9850   8861000060 2014-12-31  875000.0         3       1.00         1160
# 18433  1545801340 2014-12-31  261000.0         3       1.75         1350
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# ### What is the number of sales that took place in each month of the year?

# %%
sales.date.dt.month.value_counts().head(1)
# Out:
# 5    2414
# Name: date, dtype: int64

# %% [markdown]
# ### Which homes were sold between May 1st, 2014 and May 1st, 2015?

# %%
# Select one year of sales data between May 1, 2014 and May 1, 2015
one_year = sales[sales.date.between('2014-05-01', '2015-05-01')].sort_values('date')

# Count sales for each month and plot as a bar chart
one_year.date.dt.month.value_counts().sort_index().plot(kind='bar')

# Add labels
plt.style.use('seaborn-v0_8')
plt.title('Monthly Sales from May 1, 2014 to May 1, 2015')
plt.xlabel('Month')
plt.ylabel('Number of Sales')
# Out:
# Text(0, 0.5, 'Number of Sales')

# %% [markdown]
# ### What is the number of homesales for each day of the week?

# %%
sales.date.dt.dayofweek.value_counts()
# Out:
# 1    4715
# 2    4603
# 0    4099
# 3    3994
# 4    3685
# 5     287
# 6     230
# Name: date, dtype: int64

# %% [markdown]
# ### Creating a line plot that shows the total number of sales by week of the year

# %%
# Count number of sales by week and generate line plot
weekly_sales = sales.date.dt.isocalendar().week.value_counts().sort_index()
weekly_sales.plot(kind='line')

# Add labels and title to plot
plt.style.use('seaborn-v0_8')
plt.xlabel('Week')
plt.ylabel('Number of Sales')
plt.title('Weekly Sales')

# Display plot
plt.show()

# %% [markdown]
# ### Bar plot showing the total number of sales that took place in December.

# %%
# Extract sales data for December, January, and February
df = sales[sales.date.dt.month.isin([12, 1, 2])]

# Count number of sales by month and generate bar plot
monthly_sales = df.date.dt.month.value_counts().sort_index()
monthly_sales.plot(kind='bar')

# Add labels and title to plot
plt.style.use('seaborn-v0_8')
plt.xlabel('Month')
plt.ylabel('Number of Sales')
plt.title('Sales in Winter Months')

# Display plot
plt.show()

# %% [markdown]
# ### Which homes were sold between May 1st, 2014 and May 1st, 2015, and among those homes, how many were waterfront properties?

# %%
# Extract sales data between May 1, 2014 and May 1, 2015
df_2 = sales[sales.date.between('2014-05-01', '2015-05-01')]

# Extract sales data for waterfront properties and plot by quarter
waterfront = df[df.waterfront == 1]
waterfront_quarters = waterfront.date.dt.quarter.value_counts()

# Generate bar plot
waterfront_quarters.plot(kind='bar')

# Add labels and title to plot
plt.style.use('seaborn-v0_8')
plt.xlabel('Quarter')
plt.ylabel('Number of Sales')
plt.title('Waterfront Sales by Quarter')

# Display plot
plt.show()

# %% [markdown]
# ### What is the number of homes sold in each quarter?

# %%
# Plot sales by quarter
sales.date.dt.quarter.value_counts().plot(kind='bar')

# Add labels and title to plot
plt.style.use('seaborn-v0_8')
plt.xlabel('Quarter')
plt.ylabel('Number of Sales')
plt.title('Sales by Quarter')
plt.show()

# %% [markdown]
# ### What is the correlation between house price and various features?

# %%
# Create scatter plot of house price vs. square footage of living area
sns.scatterplot(x='sqft_living', y='price', data=sales)

# Create heatmap of correlation matrix
corr = sales.corr()
sns.heatmap(corr, cmap='coolwarm')
# Out:
# C:\Users\YaqoobDavid\AppData\Local\Temp\ipykernel_21944\145588404.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = sales.corr()
# <Axes: >

# %% [markdown]
# ### What are the most common zip codes in the dataset?

# %%
# Count frequency of each zip code and plot as a bar chart
zip_counts = sales.zipcode.value_counts().sort_index()
zip_counts.plot(kind='bar', figsize=(12,6))
plt.style.use('seaborn-v0_8')
plt.xlabel('Zip Code')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### What is the average price of houses in different zip codes?

# %%
# Group data by zip code and calculate mean house price for each group
zip_price = sales.groupby('zipcode').mean()['price'].sort_values()
print(zip_price)

# Plot mean house price for each zip code
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(12,6))
plt.bar(zip_price.index, zip_price.values)
plt.xticks(rotation=90)
plt.xlabel('Zip Code')
plt.ylabel('Mean House Price')
plt.show()
# Out:
# C:\Users\YaqoobDavid\AppData\Local\Temp\ipykernel_21944\772375121.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   zip_price = sales.groupby('zipcode').mean()['price'].sort_values()
# zipcode
# 98002    2.342840e+05
# 98168    2.403284e+05
# 98032    2.512962e+05
# 98001    2.808047e+05
# 98148    2.849086e+05
#              ...
# 98102    9.012583e+05
# 98112    1.095499e+06
# 98040    1.194230e+06
# 98004    1.355927e+06
# 98039    2.160607e+06
# Name: price, Length: 70, dtype: float64

# %% [markdown]
# ### What is the relationship between house price and the presence of a waterfront view?

# %%
# Create box plot comparing house price for homes with and without waterfront view
plt.style.use('seaborn-v0_8')
sns.boxplot(x='waterfront', y='price', data=sales)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %% [markdown]
# ### What is the relationship between house price and the quality of the view?

# %%
# Create box plot comparing house price for homes with different view quality ratings
plt.style.use('seaborn-v0_8')
sns.boxplot(x='view', y='price', data=sales)
# Out:
# <Axes: xlabel='view', ylabel='price'>

# %% [markdown]
# ### What is the relationship between house price and the year the home was built?

# %%
plt.style.use('seaborn-v0_8')
sns.scatterplot(x='yr_built', y='price', data=sales)
# Out:
# <Axes: xlabel='yr_built', ylabel='price'>

# %% [markdown]
# ### What is the relationship between house price and the average square footage of interior housing living space for the nearest 15 neighbors?

# %%
plt.style.use('seaborn-v0_8')
sns.scatterplot(x='sqft_living15', y='price', data=sales)
# Out:
# <Axes: xlabel='sqft_living15', ylabel='price'>
